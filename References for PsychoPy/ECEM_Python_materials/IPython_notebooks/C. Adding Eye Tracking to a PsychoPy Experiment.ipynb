# %%
from executeNotebook import execute_notebook
execute_notebook("Py4ET_2013_ECEM_Workshop.ipynb")

# %% [markdown]
# # Using ioHub with PsychoPy
#
# ##I.Coder Mode
#
# For this Section of the Workshop we will use the PsychoPy Coder.
#
# 1. Open the PsychoPy Coder IDE
#
#     - Start->Programs->PsychoPy2->PsychoPy
#
# 2. Ensure the IDE is in *Coder* Mode
#
#     - If title of IDE has *Coder* in it, you are in the Coder View.
#     - Otherwise, select menu View->Open Coder View.
#     - Close the Builder View.
#
# 3. Open the the GC Cursor Demo script:
#     - Select Menu File->Open
#     - Python file is found in [Worshop Materials Root]\demos\coder\gc_cursor\run.py
#
# So now you should have the PsychoPy Coder IDE open and it should look like this:

# %%
Image(filename='./psychopy_coder.png')

# %% [markdown]
# ##II. Builder Mode
#
# Now we will use the PsychoPy IDE in Builder mode, illustrating how to currently add eye tracking support to two example builder projects:
#
# 1. Stroop Effect
#     - Add fixation monitoring logic, reporting at the end of each response whether the participant maintained fixation during the trial or not.
#
# 2. Visual Search Task
#     - Adding a Gaze Contingent mask, masking either the foveal or peripheral eareas of the search array in real-time
